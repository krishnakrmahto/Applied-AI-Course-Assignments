# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.datasets import load_boston

# %%
boston_obj = load_boston() ## return python dictionary-like object (of Bunch class)

# %%
type(boston_obj)
# Out:
# sklearn.utils.Bunch

# %%
type(boston_obj.data)
# Out:
# numpy.ndarray

# %%
boston_feature_values = boston_obj.data
boston_target_values = boston_obj.target

# %%
# print(boston_obj.DESCR)

# %%
dir(boston_obj)
# Out:
# ['DESCR', 'data', 'feature_names', 'target']

# %%
boston_feature_values.shape
# Out:
# (506, 13)

# %%
boston_target_values.shape
# Out:
# (506,)

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()

std_scaler = std_scaler.fit(boston_feature_values)
boston_feature_values = std_scaler.transform(boston_feature_values)

# %%
def my_sgdRegressor(X, y, initial_weights, initial_learning_rate):
    n = X.shape[0]
    d = X.shape[1]
#     weights = initial_weights ### weights: (d X 1)
    weights = np.zeros((d, 1))
    learning_rate = initial_learning_rate
    
    iterations = 0
    while(True):
        random_row_index = np.random.randint(0, n, size = 1)
        
        random_row = X[random_row_index].reshape(d, 1) ### X[r_r_i]: a row vector (1 X d), reshaped to d X 1
#         print(random_row_index, end = ' ')
        y_pred = np.dot(weights.T, random_row) ### a real number (returned value by dot is 1 X 1 matrix)
        
        error = y[random_row_index] - y_pred ### for current randomly chosen row, error: n X 1 matrix
        
        grad = -2*error*random_row ### for current randomly chosen row; grad: d X 1
        
        preupdation_weights = weights
#         print('grad shape' + str(grad.shape))
#         print('weights.shape' + str(weights.shape))
        weights = weights - learning_rate * grad
        
        change_in_weights = weights - preupdation_weights
        distance_bw_weights = np.sqrt(np.sum(change_in_weights**2))
#         print(change_in_weights)
        if(iterations > 1 and distance_bw_weights < 0.001):
            break
               
#         learning_rate /= 2
        iterations += 1
        print('>iteration=%d, lrate=%.3f, error=%.3f' % (iterations, learning_rate, error**2))
    
    print(iterations)
    return weights

# %%
ones = np.ones(shape = (boston_feature_values.shape[0], 1))
X = np.concatenate([ones, boston_feature_values], axis = 1)

# %%
X[:2]
# Out:
# array([[ 1.        , -0.41771335,  0.28482986, -1.2879095 , -0.27259857,
#         -0.14421743,  0.41367189, -0.12001342,  0.1402136 , -0.98284286,
#         -0.66660821, -1.45900038,  0.44105193, -1.0755623 ],
#        [ 1.        , -0.41526932, -0.48772236, -0.59338101, -0.27259857,
#         -0.74026221,  0.19427445,  0.36716642,  0.55715988, -0.8678825 ,
#         -0.98732948, -0.30309415,  0.44105193, -0.49243937]])

# %%
n = X.shape[0]
d = X.shape[1]

# %%
print(n, d,sep = '\n')
# Out:
# 506
# 14

# %%
y = boston_target_values.reshape(n, 1)

# %%
initial_weights = np.random.normal(size = (d, 1)) ### initial_weights is d X 1 matrix

# %%
initial_weights.shape
# Out:
# (14, 1)

# %%
learned_weights = my_sgdRegressor(X, y, initial_weights, 0.001)
# Out:
# >iteration=1, lrate=0.001, error=841.000
# >iteration=2, lrate=0.001, error=486.303
# >iteration=3, lrate=0.001, error=65.596
# >iteration=4, lrate=0.001, error=619.800
# >iteration=5, lrate=0.001, error=298.748
# >iteration=6, lrate=0.001, error=482.134
# >iteration=7, lrate=0.001, error=573.713
# >iteration=8, lrate=0.001, error=969.119
# >iteration=9, lrate=0.001, error=1029.293
# >iteration=10, lrate=0.001, error=399.551
# >iteration=11, lrate=0.001, error=241.100
# >iteration=12, lrate=0.001, error=418.767
# >iteration=13, lrate=0.001, error=266.763
# >iteration=14, lrate=0.001, error=374.666
# >iteration=15, lrate=0.001, error=175.041
# >iteration=16, lrate=0.001, error=569.715
# >iteration=17, lrate=0.001, error=2526.875
# >iteration=18, lrate=0.001, error=592.579
# >iteration=19, lrate=0.001, error=254.602
# >iteration=20, lrate=0.001, error=1950.971
# >iteration=21, lrate=0.001, error=261.251
# >iteration=22, lrate=0.001, error=580.544
# >iteration=23, lrate=0.001, error=306.822
# >iteration=24, lrate=0.001, error=530.193
# >iteration=25, lrate=0.001, error=189.377
# >iteration=26, lrate=0.001, error=286.363
# >iteration=27, lrate=0.001, error=155.760
# >iteration=28, lrate=0.001, error=355.730
# >iteration=29, lrate=0.001, error=385.939
# >iteration=30, lrate=0.001, error=329.209
# >iteration=31, lrate=0.001, error=351.431
# >iteration=32, lrate=0.001, error=154.818
# >iteration=33, lrate=0.001, error=327.351
# >iteration=34, lrate=0.001, error=521.881
# >iteration=35, lrate=0.001, error=440.975
# >iteration=36, lrate=0.001, error=260.735
# >iteration=37, lrate=0.001, error=271.915
# >iteration=38, lrate=0.001, error=313.544
# >iteration=39, lrate=0.001, error=1472.273
# >iteration=40, lrate=0.001, error=75.846
# >iteration=41, lrate=0.001, error=404.738
# >iteration=42, lrate=0.001, error=1936.629
# >iteration=43, lrate=0.001, error=436.616
# >iteration=44, lrate=0.001, error=2228.728
# >iteration=45, lrate=0.001, error=827.654
# >iteration=46, lrate=0.001, error=119.262
# >iteration=47, lrate=0.001, error=1201.678
# >iteration=48, lrate=0.001, error=210.393
# >iteration=49, lrate=0.001, error=255.939
# >iteration=50, lrate=0.001, error=277.974
# >iteration=51, lrate=0.001, error=58.874
# >iteration=52, lrate=0.001, error=76.066
# >iteration=53, lrate=0.001, error=307.262
# >iteration=54, lrate=0.001, error=366.269
# >iteration=55, lrate=0.001, error=103.408
# >iteration=56, lrate=0.001, error=351.121
# >iteration=57, lrate=0.001, error=256.150
# >iteration=58, lrate=0.001, error=144.919
# >iteration=59, lrate=0.001, error=494.437
# >iteration=60, lrate=0.001, error=452.911
# >iteration=61, lrate=0.001, error=250.538
# >iteration=62, lrate=0.001, error=243.397
# >iteration=63, lrate=0.001, error=207.057
# >iteration=64, lrate=0.001, error=555.425
# >iteration=65, lrate=0.001, error=390.845
# >iteration=66, lrate=0.001, error=466.076
# >iteration=67, lrate=0.001, error=296.832
# >iteration=68, lrate=0.001, error=355.906
# >iteration=69, lrate=0.001, error=285.613
# >iteration=70, lrate=0.001, error=1149.379
# >iteration=71, lrate=0.001, error=228.483
# >iteration=72, lrate=0.001, error=661.865
# >iteration=73, lrate=0.001, error=1109.673
# >iteration=74, lrate=0.001, error=849.224
# >iteration=75, lrate=0.001, error=226.891
# >iteration=76, lrate=0.001, error=157.849
# >iteration=77, lrate=0.001, error=204.760
# >iteration=78, lrate=0.001, error=348.385
# >iteration=79, lrate=0.001, error=755.869
# >iteration=80, lrate=0.001, error=323.765
# >iteration=81, lrate=0.001, error=349.229
# >iteration=82, lrate=0.001, error=433.160
# >iteration=83, lrate=0.001, error=300.685
# >iteration=84, lrate=0.001, error=139.128
# >iteration=85, lrate=0.001, error=971.189
# >iteration=86, lrate=0.001, error=145.565
# >iteration=87, lrate=0.001, error=308.435
# >iteration=88, lrate=0.001, error=43.504
# >iteration=89, lrate=0.001, error=204.250
# >iteration=90, lrate=0.001, error=273.511
# >iteration=91, lrate=0.001, error=1685.134
# >iteration=92, lrate=0.001, error=1605.103
# >iteration=93, lrate=0.001, error=2038.953
# >iteration=94, lrate=0.001, error=313.342
# >iteration=95, lrate=0.001, error=516.174
# >iteration=96, lrate=0.001, error=419.475
# >iteration=97, lrate=0.001, error=239.705
# >iteration=98, lrate=0.001, error=282.949
# >iteration=99, lrate=0.001, error=172.034
# >iteration=100, lrate=0.001, error=366.926
# >iteration=101, lrate=0.001, error=218.635
# >iteration=102, lrate=0.001, error=339.077
# >iteration=103, lrate=0.001, error=232.706
# >iteration=104, lrate=0.001, error=546.032
# >iteration=105, lrate=0.001, error=278.142
# >iteration=106, lrate=0.001, error=202.418
# >iteration=107, lrate=0.001, error=163.830
# >iteration=108, lrate=0.001, error=586.962
# >iteration=109, lrate=0.001, error=216.831
# >iteration=110, lrate=0.001, error=372.753
# >iteration=111, lrate=0.001, error=1352.545
# >iteration=112, lrate=0.001, error=378.736
# >iteration=113, lrate=0.001, error=1528.843
# >iteration=114, lrate=0.001, error=219.968
# >iteration=115, lrate=0.001, error=189.728
# >iteration=116, lrate=0.001, error=558.603
# >iteration=117, lrate=0.001, error=198.753
# >iteration=118, lrate=0.001, error=577.098
# >iteration=119, lrate=0.001, error=370.107
# >iteration=120, lrate=0.001, error=258.650
# >iteration=121, lrate=0.001, error=435.234
# >iteration=122, lrate=0.001, error=337.200
# >iteration=123, lrate=0.001, error=507.993
# >iteration=124, lrate=0.001, error=129.372
# >iteration=125, lrate=0.001, error=192.530
# >iteration=126, lrate=0.001, error=231.599
# >iteration=127, lrate=0.001, error=209.038
# >iteration=128, lrate=0.001, error=624.701
# >iteration=129, lrate=0.001, error=211.463
# >iteration=130, lrate=0.001, error=511.259
# >iteration=131, lrate=0.001, error=230.508
# >iteration=132, lrate=0.001, error=617.618
# >iteration=133, lrate=0.001, error=306.624
# >iteration=134, lrate=0.001, error=159.971
# >iteration=135, lrate=0.001, error=180.649
# >iteration=136, lrate=0.001, error=219.661
# >iteration=137, lrate=0.001, error=177.106
# >iteration=138, lrate=0.001, error=289.979
# >iteration=139, lrate=0.001, error=1340.838
# >iteration=140, lrate=0.001, error=246.814
# >iteration=141, lrate=0.001, error=1637.599
# >iteration=142, lrate=0.001, error=260.373
# >iteration=143, lrate=0.001, error=402.340
# >iteration=144, lrate=0.001, error=181.680
# >iteration=145, lrate=0.001, error=142.551
# >iteration=146, lrate=0.001, error=261.478
# >iteration=147, lrate=0.001, error=227.850
# >iteration=148, lrate=0.001, error=206.868
# >iteration=149, lrate=0.001, error=168.205
# >iteration=150, lrate=0.001, error=159.231
# >iteration=151, lrate=0.001, error=480.607
# >iteration=152, lrate=0.001, error=410.667
# >iteration=153, lrate=0.001, error=359.376
# >iteration=154, lrate=0.001, error=187.726
# >iteration=155, lrate=0.001, error=204.165
# >iteration=156, lrate=0.001, error=146.760
# >iteration=157, lrate=0.001, error=190.711
# >iteration=158, lrate=0.001, error=129.505
# >iteration=159, lrate=0.001, error=180.195
# >iteration=160, lrate=0.001, error=716.031
# >iteration=161, lrate=0.001, error=199.274
# >iteration=162, lrate=0.001, error=142.335
# >iteration=163, lrate=0.001, error=398.036
# >iteration=164, lrate=0.001, error=100.668
# >iteration=165, lrate=0.001, error=195.635
# >iteration=166, lrate=0.001, error=194.425
# >iteration=167, lrate=0.001, error=223.312
# >iteration=168, lrate=0.001, error=349.878
# >iteration=169, lrate=0.001, error=274.102
# >iteration=170, lrate=0.001, error=205.946
# >iteration=171, lrate=0.001, error=179.471
# >iteration=172, lrate=0.001, error=125.887
# >iteration=173, lrate=0.001, error=95.869
# >iteration=174, lrate=0.001, error=132.710
# >iteration=175, lrate=0.001, error=422.453
# >iteration=176, lrate=0.001, error=336.797
# >iteration=177, lrate=0.001, error=173.558
# >iteration=178, lrate=0.001, error=164.107
# >iteration=179, lrate=0.001, error=346.167
# >iteration=180, lrate=0.001, error=342.300
# >iteration=181, lrate=0.001, error=143.318
# >iteration=182, lrate=0.001, error=177.171
# >iteration=183, lrate=0.001, error=100.964
# >iteration=184, lrate=0.001, error=322.942
# >iteration=185, lrate=0.001, error=304.951
# >iteration=186, lrate=0.001, error=594.192
# >iteration=187, lrate=0.001, error=124.352
# >iteration=188, lrate=0.001, error=139.655
# >iteration=189, lrate=0.001, error=260.335
# >iteration=190, lrate=0.001, error=1424.234
# >iteration=191, lrate=0.001, error=126.055
# >iteration=192, lrate=0.001, error=319.487
# >iteration=193, lrate=0.001, error=388.831
# >iteration=194, lrate=0.001, error=115.544
# >iteration=195, lrate=0.001, error=252.695
# >iteration=196, lrate=0.001, error=171.372
# >iteration=197, lrate=0.001, error=92.312
# >iteration=198, lrate=0.001, error=140.287
# >iteration=199, lrate=0.001, error=110.372
# >iteration=200, lrate=0.001, error=184.384
# >iteration=201, lrate=0.001, error=94.991
# >iteration=202, lrate=0.001, error=159.066
# >iteration=203, lrate=0.001, error=205.184
# >iteration=204, lrate=0.001, error=116.310
# >iteration=205, lrate=0.001, error=105.437
# >iteration=206, lrate=0.001, error=378.954
# >iteration=207, lrate=0.001, error=124.833
# >iteration=208, lrate=0.001, error=153.425
# >iteration=209, lrate=0.001, error=158.711
# >iteration=210, lrate=0.001, error=327.489
# >iteration=211, lrate=0.001, error=78.722
# >iteration=212, lrate=0.001, error=106.162
# >iteration=213, lrate=0.001, error=959.624
# >iteration=214, lrate=0.001, error=34.984
# >iteration=215, lrate=0.001, error=105.568
# >iteration=216, lrate=0.001, error=153.289
# >iteration=217, lrate=0.001, error=164.964
# >iteration=218, lrate=0.001, error=74.459
# >iteration=219, lrate=0.001, error=239.322
# >iteration=220, lrate=0.001, error=357.416
# >iteration=221, lrate=0.001, error=267.051
# >iteration=222, lrate=0.001, error=157.099
# >iteration=223, lrate=0.001, error=565.464
# >iteration=224, lrate=0.001, error=123.713
# >iteration=225, lrate=0.001, error=42.913
# >iteration=226, lrate=0.001, error=101.196
# >iteration=227, lrate=0.001, error=82.287
# >iteration=228, lrate=0.001, error=222.052
# >iteration=229, lrate=0.001, error=262.477
# >iteration=230, lrate=0.001, error=201.198
# >iteration=231, lrate=0.001, error=124.706
# >iteration=232, lrate=0.001, error=410.043
# >iteration=233, lrate=0.001, error=333.820
# >iteration=234, lrate=0.001, error=229.727
# >iteration=235, lrate=0.001, error=142.057
# >iteration=236, lrate=0.001, error=218.365
# >iteration=237, lrate=0.001, error=208.914
# >iteration=238, lrate=0.001, error=234.075
# >iteration=239, lrate=0.001, error=406.602
# >iteration=240, lrate=0.001, error=90.269
# >iteration=241, lrate=0.001, error=359.371
# >iteration=242, lrate=0.001, error=114.992
# >iteration=243, lrate=0.001, error=68.739
# >iteration=244, lrate=0.001, error=81.355
# >iteration=245, lrate=0.001, error=78.920
# >iteration=246, lrate=0.001, error=235.736
# >iteration=247, lrate=0.001, error=94.610
# >iteration=248, lrate=0.001, error=54.596
# >iteration=249, lrate=0.001, error=225.523
# >iteration=250, lrate=0.001, error=839.101
# >iteration=251, lrate=0.001, error=125.049
# >iteration=252, lrate=0.001, error=90.397
# >iteration=253, lrate=0.001, error=82.636
# >iteration=254, lrate=0.001, error=389.456
# >iteration=255, lrate=0.001, error=2241.522
# >iteration=256, lrate=0.001, error=196.755
# >iteration=257, lrate=0.001, error=448.415
# >iteration=258, lrate=0.001, error=182.640
# >iteration=259, lrate=0.001, error=222.480
# >iteration=260, lrate=0.001, error=96.858
# >iteration=261, lrate=0.001, error=178.667
# >iteration=262, lrate=0.001, error=98.176
# >iteration=263, lrate=0.001, error=65.923
# >iteration=264, lrate=0.001, error=87.781
# >iteration=265, lrate=0.001, error=192.734
# >iteration=266, lrate=0.001, error=164.569
# >iteration=267, lrate=0.001, error=254.412
# >iteration=268, lrate=0.001, error=75.933
# >iteration=269, lrate=0.001, error=117.074
# >iteration=270, lrate=0.001, error=336.416
# >iteration=271, lrate=0.001, error=260.133
# >iteration=272, lrate=0.001, error=322.049
# >iteration=273, lrate=0.001, error=257.288
# >iteration=274, lrate=0.001, error=36.444
# >iteration=275, lrate=0.001, error=86.766
# >iteration=276, lrate=0.001, error=165.848
# >iteration=277, lrate=0.001, error=240.477
# >iteration=278, lrate=0.001, error=254.468
# >iteration=279, lrate=0.001, error=172.650
# >iteration=280, lrate=0.001, error=49.872
# >iteration=281, lrate=0.001, error=80.109
# >iteration=282, lrate=0.001, error=78.080
# >iteration=283, lrate=0.001, error=83.354
# >iteration=284, lrate=0.001, error=174.508
# >iteration=285, lrate=0.001, error=77.268
# >iteration=286, lrate=0.001, error=147.721
# >iteration=287, lrate=0.001, error=743.181
# >iteration=288, lrate=0.001, error=205.916
# >iteration=289, lrate=0.001, error=68.281
# >iteration=290, lrate=0.001, error=517.877
# >iteration=291, lrate=0.001, error=163.999
# >iteration=292, lrate=0.001, error=87.894
# >iteration=293, lrate=0.001, error=71.804
# >iteration=294, lrate=0.001, error=146.858
# >iteration=295, lrate=0.001, error=226.159
# >iteration=296, lrate=0.001, error=529.024
# >iteration=297, lrate=0.001, error=70.029
# >iteration=298, lrate=0.001, error=238.861
# >iteration=299, lrate=0.001, error=79.683
# >iteration=300, lrate=0.001, error=188.063
# >iteration=301, lrate=0.001, error=72.318
# >iteration=302, lrate=0.001, error=158.715
# >iteration=303, lrate=0.001, error=17.548
# >iteration=304, lrate=0.001, error=79.844
# >iteration=305, lrate=0.001, error=461.462
# >iteration=306, lrate=0.001, error=63.402
# >iteration=307, lrate=0.001, error=99.207
# >iteration=308, lrate=0.001, error=371.695
# >iteration=309, lrate=0.001, error=28.059
# >iteration=310, lrate=0.001, error=68.977
# >iteration=311, lrate=0.001, error=211.922
# >iteration=312, lrate=0.001, error=178.731
# >iteration=313, lrate=0.001, error=61.656
# >iteration=314, lrate=0.001, error=88.838
# >iteration=315, lrate=0.001, error=73.848
# >iteration=316, lrate=0.001, error=160.806
# >iteration=317, lrate=0.001, error=53.122
# >iteration=318, lrate=0.001, error=96.364
# >iteration=319, lrate=0.001, error=150.105
# >iteration=320, lrate=0.001, error=545.415
# >iteration=321, lrate=0.001, error=337.940
# >iteration=322, lrate=0.001, error=164.690
# >iteration=323, lrate=0.001, error=29.301
# >iteration=324, lrate=0.001, error=102.013
# >iteration=325, lrate=0.001, error=250.704
# >iteration=326, lrate=0.001, error=127.670
# >iteration=327, lrate=0.001, error=104.895
# >iteration=328, lrate=0.001, error=215.306
# >iteration=329, lrate=0.001, error=138.650
# >iteration=330, lrate=0.001, error=616.993
# >iteration=331, lrate=0.001, error=55.486
# >iteration=332, lrate=0.001, error=232.780
# >iteration=333, lrate=0.001, error=65.058
# >iteration=334, lrate=0.001, error=825.249
# >iteration=335, lrate=0.001, error=137.672
# >iteration=336, lrate=0.001, error=65.143
# >iteration=337, lrate=0.001, error=60.978
# >iteration=338, lrate=0.001, error=36.092
# >iteration=339, lrate=0.001, error=131.162
# >iteration=340, lrate=0.001, error=67.835
# >iteration=341, lrate=0.001, error=184.970
# >iteration=342, lrate=0.001, error=99.828
# >iteration=343, lrate=0.001, error=47.113
# >iteration=344, lrate=0.001, error=108.495
# >iteration=345, lrate=0.001, error=123.321
# >iteration=346, lrate=0.001, error=518.566
# >iteration=347, lrate=0.001, error=752.342
# >iteration=348, lrate=0.001, error=97.612
# >iteration=349, lrate=0.001, error=162.944
# >iteration=350, lrate=0.001, error=28.333
# >iteration=351, lrate=0.001, error=573.833
# >iteration=352, lrate=0.001, error=80.484
# >iteration=353, lrate=0.001, error=82.486
# >iteration=354, lrate=0.001, error=41.323
# >iteration=355, lrate=0.001, error=303.164
# >iteration=356, lrate=0.001, error=1007.260
# >iteration=357, lrate=0.001, error=53.402
# >iteration=358, lrate=0.001, error=66.831
# >iteration=359, lrate=0.001, error=201.311
# >iteration=360, lrate=0.001, error=35.844
# >iteration=361, lrate=0.001, error=97.961
# >iteration=362, lrate=0.001, error=36.525
# >iteration=363, lrate=0.001, error=62.074
# >iteration=364, lrate=0.001, error=43.383
# >iteration=365, lrate=0.001, error=98.694
# >iteration=366, lrate=0.001, error=202.905
# >iteration=367, lrate=0.001, error=287.864
# >iteration=368, lrate=0.001, error=126.174
# >iteration=369, lrate=0.001, error=67.150
# >iteration=370, lrate=0.001, error=37.939
# >iteration=371, lrate=0.001, error=952.359
# >iteration=372, lrate=0.001, error=165.667
# >iteration=373, lrate=0.001, error=46.372
# >iteration=374, lrate=0.001, error=120.091
# >iteration=375, lrate=0.001, error=119.704
# >iteration=376, lrate=0.001, error=35.586
# >iteration=377, lrate=0.001, error=96.470
# >iteration=378, lrate=0.001, error=275.511
# >iteration=379, lrate=0.001, error=158.014
# >iteration=380, lrate=0.001, error=112.657
# >iteration=381, lrate=0.001, error=86.506
# >iteration=382, lrate=0.001, error=22.864
# >iteration=383, lrate=0.001, error=82.208
# >iteration=384, lrate=0.001, error=68.590
# >iteration=385, lrate=0.001, error=41.340
# >iteration=386, lrate=0.001, error=52.738
# >iteration=387, lrate=0.001, error=113.955
# >iteration=388, lrate=0.001, error=110.409
# >iteration=389, lrate=0.001, error=164.028
# >iteration=390, lrate=0.001, error=334.270
# >iteration=391, lrate=0.001, error=50.214
# >iteration=392, lrate=0.001, error=111.149
# >iteration=393, lrate=0.001, error=33.517
# >iteration=394, lrate=0.001, error=46.562
# >iteration=395, lrate=0.001, error=54.922
# >iteration=396, lrate=0.001, error=103.855
# >iteration=397, lrate=0.001, error=21.307
# >iteration=398, lrate=0.001, error=27.746
# >iteration=399, lrate=0.001, error=183.953
# >iteration=400, lrate=0.001, error=27.407
# >iteration=401, lrate=0.001, error=87.535
# >iteration=402, lrate=0.001, error=84.689
# >iteration=403, lrate=0.001, error=151.497
# >iteration=404, lrate=0.001, error=496.042
# >iteration=405, lrate=0.001, error=341.597
# >iteration=406, lrate=0.001, error=19.767
# >iteration=407, lrate=0.001, error=53.966
# >iteration=408, lrate=0.001, error=98.416
# >iteration=409, lrate=0.001, error=41.095
# >iteration=410, lrate=0.001, error=115.921
# >iteration=411, lrate=0.001, error=19.801
# >iteration=412, lrate=0.001, error=42.983
# >iteration=413, lrate=0.001, error=76.149
# >iteration=414, lrate=0.001, error=84.711
# >iteration=415, lrate=0.001, error=75.213
# >iteration=416, lrate=0.001, error=20.586
# >iteration=417, lrate=0.001, error=121.540
# >iteration=418, lrate=0.001, error=33.957
# >iteration=419, lrate=0.001, error=28.103
# >iteration=420, lrate=0.001, error=563.320
# >iteration=421, lrate=0.001, error=23.132
# >iteration=422, lrate=0.001, error=102.647
# >iteration=423, lrate=0.001, error=21.114
# >iteration=424, lrate=0.001, error=55.077
# >iteration=425, lrate=0.001, error=154.924
# >iteration=426, lrate=0.001, error=194.987
# >iteration=427, lrate=0.001, error=226.186
# >iteration=428, lrate=0.001, error=534.448
# >iteration=429, lrate=0.001, error=52.844
# >iteration=430, lrate=0.001, error=205.595
# >iteration=431, lrate=0.001, error=647.391
# >iteration=432, lrate=0.001, error=546.289
# >iteration=433, lrate=0.001, error=131.295
# >iteration=434, lrate=0.001, error=51.098
# >iteration=435, lrate=0.001, error=48.618
# >iteration=436, lrate=0.001, error=149.194
# >iteration=437, lrate=0.001, error=141.380
# >iteration=438, lrate=0.001, error=597.636
# >iteration=439, lrate=0.001, error=23.941
# >iteration=440, lrate=0.001, error=64.973
# >iteration=441, lrate=0.001, error=23.354
# >iteration=442, lrate=0.001, error=63.628
# >iteration=443, lrate=0.001, error=38.679
# >iteration=444, lrate=0.001, error=57.010
# >iteration=445, lrate=0.001, error=49.344
# >iteration=446, lrate=0.001, error=64.208
# >iteration=447, lrate=0.001, error=39.096
# >iteration=448, lrate=0.001, error=69.530
# >iteration=449, lrate=0.001, error=96.332
# >iteration=450, lrate=0.001, error=7.619
# >iteration=451, lrate=0.001, error=215.358
# >iteration=452, lrate=0.001, error=29.021
# >iteration=453, lrate=0.001, error=378.475
# >iteration=454, lrate=0.001, error=842.665
# >iteration=455, lrate=0.001, error=27.581
# >iteration=456, lrate=0.001, error=107.728
# >iteration=457, lrate=0.001, error=220.832
# >iteration=458, lrate=0.001, error=258.799
# >iteration=459, lrate=0.001, error=469.365
# >iteration=460, lrate=0.001, error=140.704
# >iteration=461, lrate=0.001, error=104.510
# >iteration=462, lrate=0.001, error=143.545
# >iteration=463, lrate=0.001, error=6.955
# >iteration=464, lrate=0.001, error=171.734
# >iteration=465, lrate=0.001, error=415.812
# >iteration=466, lrate=0.001, error=29.531
# >iteration=467, lrate=0.001, error=117.010
# >iteration=468, lrate=0.001, error=92.427
# >iteration=469, lrate=0.001, error=130.899
# >iteration=470, lrate=0.001, error=61.224
# >iteration=471, lrate=0.001, error=200.182
# >iteration=472, lrate=0.001, error=19.862
# >iteration=473, lrate=0.001, error=142.886
# >iteration=474, lrate=0.001, error=11.602
# >iteration=475, lrate=0.001, error=129.553
# >iteration=476, lrate=0.001, error=66.984
# >iteration=477, lrate=0.001, error=77.487
# >iteration=478, lrate=0.001, error=72.860
# >iteration=479, lrate=0.001, error=68.789
# >iteration=480, lrate=0.001, error=16.351
# >iteration=481, lrate=0.001, error=51.802
# >iteration=482, lrate=0.001, error=94.087
# >iteration=483, lrate=0.001, error=136.036
# >iteration=484, lrate=0.001, error=186.064
# >iteration=485, lrate=0.001, error=36.518
# >iteration=486, lrate=0.001, error=75.274
# >iteration=487, lrate=0.001, error=388.033
# >iteration=488, lrate=0.001, error=31.109
# >iteration=489, lrate=0.001, error=29.912
# >iteration=490, lrate=0.001, error=16.571
# >iteration=491, lrate=0.001, error=8.796
# >iteration=492, lrate=0.001, error=138.897
# >iteration=493, lrate=0.001, error=261.472
# >iteration=494, lrate=0.001, error=5.638
# >iteration=495, lrate=0.001, error=113.001
# >iteration=496, lrate=0.001, error=28.138
# >iteration=497, lrate=0.001, error=38.956
# >iteration=498, lrate=0.001, error=33.752
# >iteration=499, lrate=0.001, error=464.657
# >iteration=500, lrate=0.001, error=14.298
# >iteration=501, lrate=0.001, error=34.857
# >iteration=502, lrate=0.001, error=846.013
# >iteration=503, lrate=0.001, error=30.016
# >iteration=504, lrate=0.001, error=25.148
# >iteration=505, lrate=0.001, error=139.636
# >iteration=506, lrate=0.001, error=20.670
# >iteration=507, lrate=0.001, error=108.713
# >iteration=508, lrate=0.001, error=67.094
# >iteration=509, lrate=0.001, error=285.061
# >iteration=510, lrate=0.001, error=14.781
# >iteration=511, lrate=0.001, error=126.157
# >iteration=512, lrate=0.001, error=77.973
# >iteration=513, lrate=0.001, error=430.361
# >iteration=514, lrate=0.001, error=18.382
# >iteration=515, lrate=0.001, error=2.350
# >iteration=516, lrate=0.001, error=19.523
# >iteration=517, lrate=0.001, error=14.137
# >iteration=518, lrate=0.001, error=1.993
# >iteration=519, lrate=0.001, error=140.153
# >iteration=520, lrate=0.001, error=14.669
# >iteration=521, lrate=0.001, error=29.279
# >iteration=522, lrate=0.001, error=98.826
# >iteration=523, lrate=0.001, error=102.904
# >iteration=524, lrate=0.001, error=19.127
# >iteration=525, lrate=0.001, error=45.386
# >iteration=526, lrate=0.001, error=169.073
# >iteration=527, lrate=0.001, error=87.246
# >iteration=528, lrate=0.001, error=109.042
# >iteration=529, lrate=0.001, error=102.526
# >iteration=530, lrate=0.001, error=331.691
# >iteration=531, lrate=0.001, error=43.389
# >iteration=532, lrate=0.001, error=76.982
# >iteration=533, lrate=0.001, error=42.855
# >iteration=534, lrate=0.001, error=464.178
# >iteration=535, lrate=0.001, error=67.259
# >iteration=536, lrate=0.001, error=26.060
# >iteration=537, lrate=0.001, error=2.613
# >iteration=538, lrate=0.001, error=434.395
# >iteration=539, lrate=0.001, error=55.755
# >iteration=540, lrate=0.001, error=1.232
# >iteration=541, lrate=0.001, error=74.593
# >iteration=542, lrate=0.001, error=7.810
# >iteration=543, lrate=0.001, error=11.635
# >iteration=544, lrate=0.001, error=2.723
# >iteration=545, lrate=0.001, error=15.773
# >iteration=546, lrate=0.001, error=32.969
# >iteration=547, lrate=0.001, error=19.294
# >iteration=548, lrate=0.001, error=36.315
# >iteration=549, lrate=0.001, error=290.525
# >iteration=550, lrate=0.001, error=38.043
# >iteration=551, lrate=0.001, error=17.713
# >iteration=552, lrate=0.001, error=96.308
# >iteration=553, lrate=0.001, error=40.156
# >iteration=554, lrate=0.001, error=4.712
# >iteration=555, lrate=0.001, error=63.908
# >iteration=556, lrate=0.001, error=71.755
# >iteration=557, lrate=0.001, error=22.198
# >iteration=558, lrate=0.001, error=75.220
# >iteration=559, lrate=0.001, error=21.095
# >iteration=560, lrate=0.001, error=11.631
# >iteration=561, lrate=0.001, error=19.301
# >iteration=562, lrate=0.001, error=33.275
# >iteration=563, lrate=0.001, error=44.533
# >iteration=564, lrate=0.001, error=3.332
# >iteration=565, lrate=0.001, error=33.657
# >iteration=566, lrate=0.001, error=1.254
# >iteration=567, lrate=0.001, error=66.485
# >iteration=568, lrate=0.001, error=93.411
# >iteration=569, lrate=0.001, error=25.975
# >iteration=570, lrate=0.001, error=38.124
# >iteration=571, lrate=0.001, error=109.867
# >iteration=572, lrate=0.001, error=93.021
# >iteration=573, lrate=0.001, error=19.030
# >iteration=574, lrate=0.001, error=47.851
# >iteration=575, lrate=0.001, error=42.156
# >iteration=576, lrate=0.001, error=20.035
# >iteration=577, lrate=0.001, error=5.138
# >iteration=578, lrate=0.001, error=10.296
# >iteration=579, lrate=0.001, error=17.348
# >iteration=580, lrate=0.001, error=9.931
# >iteration=581, lrate=0.001, error=27.226
# >iteration=582, lrate=0.001, error=25.308
# >iteration=583, lrate=0.001, error=124.027
# >iteration=584, lrate=0.001, error=9.356
# >iteration=585, lrate=0.001, error=14.987
# >iteration=586, lrate=0.001, error=73.752
# >iteration=587, lrate=0.001, error=12.553
# >iteration=588, lrate=0.001, error=51.221
# >iteration=589, lrate=0.001, error=21.423
# >iteration=590, lrate=0.001, error=157.017
# >iteration=591, lrate=0.001, error=27.106
# >iteration=592, lrate=0.001, error=17.368
# >iteration=593, lrate=0.001, error=3.344
# >iteration=594, lrate=0.001, error=12.843
# >iteration=595, lrate=0.001, error=25.677
# >iteration=596, lrate=0.001, error=12.592
# >iteration=597, lrate=0.001, error=1.115
# >iteration=598, lrate=0.001, error=15.796
# >iteration=599, lrate=0.001, error=44.644
# >iteration=600, lrate=0.001, error=104.059
# >iteration=601, lrate=0.001, error=13.297
# >iteration=602, lrate=0.001, error=0.354
# >iteration=603, lrate=0.001, error=115.899
# >iteration=604, lrate=0.001, error=6.716
# >iteration=605, lrate=0.001, error=25.530
# >iteration=606, lrate=0.001, error=23.382
# >iteration=607, lrate=0.001, error=77.265
# >iteration=608, lrate=0.001, error=9.455
# >iteration=609, lrate=0.001, error=94.422
# >iteration=610, lrate=0.001, error=7.449
# >iteration=611, lrate=0.001, error=28.894
# >iteration=612, lrate=0.001, error=41.938
# >iteration=613, lrate=0.001, error=46.887
# >iteration=614, lrate=0.001, error=89.725
# >iteration=615, lrate=0.001, error=84.778
# >iteration=616, lrate=0.001, error=22.816
# >iteration=617, lrate=0.001, error=38.905
# >iteration=618, lrate=0.001, error=76.361
# >iteration=619, lrate=0.001, error=99.722
# >iteration=620, lrate=0.001, error=49.490
# >iteration=621, lrate=0.001, error=27.150
# >iteration=622, lrate=0.001, error=47.351
# >iteration=623, lrate=0.001, error=22.275
# >iteration=624, lrate=0.001, error=27.903
# >iteration=625, lrate=0.001, error=22.988
# >iteration=626, lrate=0.001, error=51.113
# >iteration=627, lrate=0.001, error=10.016
# >iteration=628, lrate=0.001, error=37.648
# >iteration=629, lrate=0.001, error=11.926
# >iteration=630, lrate=0.001, error=187.781
# >iteration=631, lrate=0.001, error=293.152
# >iteration=632, lrate=0.001, error=0.122
# >iteration=633, lrate=0.001, error=17.882
# >iteration=634, lrate=0.001, error=31.701
# >iteration=635, lrate=0.001, error=25.767
# >iteration=636, lrate=0.001, error=37.681
# >iteration=637, lrate=0.001, error=2.416
# >iteration=638, lrate=0.001, error=136.877
# >iteration=639, lrate=0.001, error=8.022
# >iteration=640, lrate=0.001, error=0.516
# >iteration=641, lrate=0.001, error=8.990
# >iteration=642, lrate=0.001, error=29.460
# >iteration=643, lrate=0.001, error=1.640
# >iteration=644, lrate=0.001, error=9.574
# >iteration=645, lrate=0.001, error=33.191
# >iteration=646, lrate=0.001, error=79.643
# >iteration=647, lrate=0.001, error=352.680
# >iteration=648, lrate=0.001, error=43.980
# >iteration=649, lrate=0.001, error=8.330
# >iteration=650, lrate=0.001, error=6.771
# >iteration=651, lrate=0.001, error=33.869
# >iteration=652, lrate=0.001, error=8.940
# >iteration=653, lrate=0.001, error=87.586
# >iteration=654, lrate=0.001, error=37.850
# >iteration=655, lrate=0.001, error=0.266
# >iteration=656, lrate=0.001, error=57.790
# >iteration=657, lrate=0.001, error=6.613
# >iteration=658, lrate=0.001, error=13.704
# >iteration=659, lrate=0.001, error=7.193
# >iteration=660, lrate=0.001, error=70.175
# >iteration=661, lrate=0.001, error=385.178
# >iteration=662, lrate=0.001, error=28.065
# >iteration=663, lrate=0.001, error=7.276
# >iteration=664, lrate=0.001, error=38.612
# >iteration=665, lrate=0.001, error=117.079
# >iteration=666, lrate=0.001, error=39.058
# >iteration=667, lrate=0.001, error=82.718
# >iteration=668, lrate=0.001, error=9.935
# >iteration=669, lrate=0.001, error=3.304
# >iteration=670, lrate=0.001, error=1.382
# >iteration=671, lrate=0.001, error=47.303
# >iteration=672, lrate=0.001, error=58.018
# >iteration=673, lrate=0.001, error=64.335
# >iteration=674, lrate=0.001, error=13.009
# >iteration=675, lrate=0.001, error=31.098
# >iteration=676, lrate=0.001, error=16.149
# >iteration=677, lrate=0.001, error=11.903
# >iteration=678, lrate=0.001, error=23.332
# >iteration=679, lrate=0.001, error=12.003
# >iteration=680, lrate=0.001, error=4.362
# >iteration=681, lrate=0.001, error=124.057
# >iteration=682, lrate=0.001, error=5.420
# >iteration=683, lrate=0.001, error=1.741
# >iteration=684, lrate=0.001, error=12.176
# >iteration=685, lrate=0.001, error=49.674
# >iteration=686, lrate=0.001, error=314.103
# >iteration=687, lrate=0.001, error=601.166
# >iteration=688, lrate=0.001, error=1.005
# >iteration=689, lrate=0.001, error=4.153
# >iteration=690, lrate=0.001, error=2.077
# >iteration=691, lrate=0.001, error=28.809
# >iteration=692, lrate=0.001, error=370.351
# >iteration=693, lrate=0.001, error=0.344
# >iteration=694, lrate=0.001, error=490.383
# >iteration=695, lrate=0.001, error=63.576
# >iteration=696, lrate=0.001, error=21.636
# >iteration=697, lrate=0.001, error=3.076
# >iteration=698, lrate=0.001, error=6.439
# >iteration=699, lrate=0.001, error=55.628
# >iteration=700, lrate=0.001, error=11.303
# >iteration=701, lrate=0.001, error=24.658
# >iteration=702, lrate=0.001, error=23.806
# >iteration=703, lrate=0.001, error=0.584
# >iteration=704, lrate=0.001, error=10.886
# >iteration=705, lrate=0.001, error=42.428
# >iteration=706, lrate=0.001, error=5.893
# >iteration=707, lrate=0.001, error=28.151
# >iteration=708, lrate=0.001, error=10.698
# >iteration=709, lrate=0.001, error=0.106
# >iteration=710, lrate=0.001, error=11.310
# >iteration=711, lrate=0.001, error=3.016
# >iteration=712, lrate=0.001, error=0.419
# >iteration=713, lrate=0.001, error=54.940
# >iteration=714, lrate=0.001, error=32.786
# >iteration=715, lrate=0.001, error=77.524
# >iteration=716, lrate=0.001, error=6.839
# >iteration=717, lrate=0.001, error=7.541
# >iteration=718, lrate=0.001, error=15.733
# >iteration=719, lrate=0.001, error=7.068
# >iteration=720, lrate=0.001, error=0.886
# >iteration=721, lrate=0.001, error=10.376
# >iteration=722, lrate=0.001, error=11.918
# >iteration=723, lrate=0.001, error=39.902
# >iteration=724, lrate=0.001, error=127.437
# >iteration=725, lrate=0.001, error=12.578
# >iteration=726, lrate=0.001, error=13.924
# >iteration=727, lrate=0.001, error=5.335
# >iteration=728, lrate=0.001, error=15.432
# >iteration=729, lrate=0.001, error=49.127
# >iteration=730, lrate=0.001, error=19.275
# >iteration=731, lrate=0.001, error=61.281
# >iteration=732, lrate=0.001, error=4.272
# >iteration=733, lrate=0.001, error=6.979
# >iteration=734, lrate=0.001, error=10.734
# >iteration=735, lrate=0.001, error=5.565
# >iteration=736, lrate=0.001, error=10.616
# >iteration=737, lrate=0.001, error=36.429
# >iteration=738, lrate=0.001, error=231.350
# >iteration=739, lrate=0.001, error=50.616
# >iteration=740, lrate=0.001, error=1.748
# >iteration=741, lrate=0.001, error=12.256
# >iteration=742, lrate=0.001, error=1.589
# >iteration=743, lrate=0.001, error=11.126
# >iteration=744, lrate=0.001, error=16.719
# >iteration=745, lrate=0.001, error=16.704
# >iteration=746, lrate=0.001, error=6.964
# >iteration=747, lrate=0.001, error=17.750
# >iteration=748, lrate=0.001, error=0.910
# >iteration=749, lrate=0.001, error=30.541
# >iteration=750, lrate=0.001, error=10.148
# >iteration=751, lrate=0.001, error=192.209
# >iteration=752, lrate=0.001, error=1.784
# >iteration=753, lrate=0.001, error=0.069
# >iteration=754, lrate=0.001, error=0.618
# >iteration=755, lrate=0.001, error=7.963
# >iteration=756, lrate=0.001, error=3.510
# >iteration=757, lrate=0.001, error=28.325
# >iteration=758, lrate=0.001, error=9.710
# >iteration=759, lrate=0.001, error=49.072
# >iteration=760, lrate=0.001, error=33.567
# >iteration=761, lrate=0.001, error=14.000
# >iteration=762, lrate=0.001, error=0.231
# >iteration=763, lrate=0.001, error=0.243
# >iteration=764, lrate=0.001, error=11.872
# >iteration=765, lrate=0.001, error=0.786
# >iteration=766, lrate=0.001, error=37.067
# >iteration=767, lrate=0.001, error=0.315
# >iteration=768, lrate=0.001, error=8.426
# >iteration=769, lrate=0.001, error=4.485
# >iteration=770, lrate=0.001, error=7.216
# >iteration=771, lrate=0.001, error=60.473
# >iteration=772, lrate=0.001, error=8.976
# >iteration=773, lrate=0.001, error=10.962
# >iteration=774, lrate=0.001, error=5.780
# >iteration=775, lrate=0.001, error=51.545
# >iteration=776, lrate=0.001, error=110.787
# >iteration=777, lrate=0.001, error=0.644
# >iteration=778, lrate=0.001, error=66.880
# >iteration=779, lrate=0.001, error=32.883
# >iteration=780, lrate=0.001, error=33.539
# >iteration=781, lrate=0.001, error=18.737
# >iteration=782, lrate=0.001, error=14.338
# >iteration=783, lrate=0.001, error=5.813
# >iteration=784, lrate=0.001, error=1.454
# >iteration=785, lrate=0.001, error=7.499
# >iteration=786, lrate=0.001, error=18.925
# >iteration=787, lrate=0.001, error=68.589
# >iteration=788, lrate=0.001, error=4.323
# >iteration=789, lrate=0.001, error=18.718
# >iteration=790, lrate=0.001, error=54.257
# >iteration=791, lrate=0.001, error=0.142
# >iteration=792, lrate=0.001, error=68.840
# >iteration=793, lrate=0.001, error=11.177
# >iteration=794, lrate=0.001, error=22.482
# >iteration=795, lrate=0.001, error=12.719
# >iteration=796, lrate=0.001, error=90.642
# >iteration=797, lrate=0.001, error=3.626
# >iteration=798, lrate=0.001, error=13.359
# >iteration=799, lrate=0.001, error=38.338
# >iteration=800, lrate=0.001, error=59.106
# >iteration=801, lrate=0.001, error=11.705
# >iteration=802, lrate=0.001, error=14.359
# >iteration=803, lrate=0.001, error=6.691
# >iteration=804, lrate=0.001, error=10.443
# >iteration=805, lrate=0.001, error=36.138
# >iteration=806, lrate=0.001, error=2.588
# >iteration=807, lrate=0.001, error=0.196
# >iteration=808, lrate=0.001, error=39.864
# >iteration=809, lrate=0.001, error=21.810
# >iteration=810, lrate=0.001, error=37.505
# >iteration=811, lrate=0.001, error=49.521
# >iteration=812, lrate=0.001, error=43.008
# >iteration=813, lrate=0.001, error=6.906
# >iteration=814, lrate=0.001, error=0.394
# >iteration=815, lrate=0.001, error=12.962
# >iteration=816, lrate=0.001, error=1.525
# >iteration=817, lrate=0.001, error=80.803
# >iteration=818, lrate=0.001, error=0.132
# >iteration=819, lrate=0.001, error=49.800
# >iteration=820, lrate=0.001, error=2.548
# >iteration=821, lrate=0.001, error=7.812
# >iteration=822, lrate=0.001, error=8.384
# >iteration=823, lrate=0.001, error=14.170
# >iteration=824, lrate=0.001, error=8.457
# >iteration=825, lrate=0.001, error=857.449
# >iteration=826, lrate=0.001, error=51.908
# >iteration=827, lrate=0.001, error=2.159
# >iteration=828, lrate=0.001, error=19.912
# >iteration=829, lrate=0.001, error=23.004
# >iteration=830, lrate=0.001, error=25.008
# >iteration=831, lrate=0.001, error=19.565
# >iteration=832, lrate=0.001, error=0.469
# >iteration=833, lrate=0.001, error=0.026
# >iteration=834, lrate=0.001, error=52.263
# >iteration=835, lrate=0.001, error=9.762
# >iteration=836, lrate=0.001, error=0.405
# >iteration=837, lrate=0.001, error=4.429
# >iteration=838, lrate=0.001, error=0.457
# >iteration=839, lrate=0.001, error=5.843
# >iteration=840, lrate=0.001, error=109.556
# >iteration=841, lrate=0.001, error=0.235
# >iteration=842, lrate=0.001, error=32.142
# >iteration=843, lrate=0.001, error=12.306
# >iteration=844, lrate=0.001, error=7.417
# >iteration=845, lrate=0.001, error=0.185
# >iteration=846, lrate=0.001, error=40.200
# >iteration=847, lrate=0.001, error=114.845
# >iteration=848, lrate=0.001, error=1.916
# >iteration=849, lrate=0.001, error=59.965
# >iteration=850, lrate=0.001, error=31.346
# >iteration=851, lrate=0.001, error=100.400
# >iteration=852, lrate=0.001, error=56.808
# >iteration=853, lrate=0.001, error=8.798
# >iteration=854, lrate=0.001, error=8.587
# >iteration=855, lrate=0.001, error=88.642
# >iteration=856, lrate=0.001, error=237.540
# >iteration=857, lrate=0.001, error=25.812
# >iteration=858, lrate=0.001, error=18.241
# >iteration=859, lrate=0.001, error=0.102
# >iteration=860, lrate=0.001, error=80.455
# >iteration=861, lrate=0.001, error=48.705
# >iteration=862, lrate=0.001, error=0.071
# >iteration=863, lrate=0.001, error=17.286
# >iteration=864, lrate=0.001, error=0.121
# >iteration=865, lrate=0.001, error=17.092
# >iteration=866, lrate=0.001, error=2.788
# >iteration=867, lrate=0.001, error=6.911
# >iteration=868, lrate=0.001, error=22.010
# >iteration=869, lrate=0.001, error=0.665
# >iteration=870, lrate=0.001, error=3.668
# >iteration=871, lrate=0.001, error=4.906
# >iteration=872, lrate=0.001, error=5.016
# >iteration=873, lrate=0.001, error=2.381
# >iteration=874, lrate=0.001, error=2.590
# >iteration=875, lrate=0.001, error=5.690
# >iteration=876, lrate=0.001, error=127.534
# >iteration=877, lrate=0.001, error=38.907
# >iteration=878, lrate=0.001, error=213.767
# >iteration=879, lrate=0.001, error=2.475
# >iteration=880, lrate=0.001, error=1.956
# >iteration=881, lrate=0.001, error=282.049
# >iteration=882, lrate=0.001, error=2.705
# >iteration=883, lrate=0.001, error=2.481
# >iteration=884, lrate=0.001, error=0.255
# >iteration=885, lrate=0.001, error=13.603
# >iteration=886, lrate=0.001, error=32.740
# >iteration=887, lrate=0.001, error=0.357
# >iteration=888, lrate=0.001, error=29.309
# >iteration=889, lrate=0.001, error=71.214
# >iteration=890, lrate=0.001, error=25.279
# >iteration=891, lrate=0.001, error=2.775
# >iteration=892, lrate=0.001, error=216.474
# >iteration=893, lrate=0.001, error=3.357
# >iteration=894, lrate=0.001, error=2.987
# >iteration=895, lrate=0.001, error=93.888
# >iteration=896, lrate=0.001, error=47.707
# >iteration=897, lrate=0.001, error=169.919
# >iteration=898, lrate=0.001, error=5.329
# >iteration=899, lrate=0.001, error=266.937
# >iteration=900, lrate=0.001, error=73.552
# >iteration=901, lrate=0.001, error=4.424
# >iteration=902, lrate=0.001, error=27.490
# >iteration=903, lrate=0.001, error=10.735
# >iteration=904, lrate=0.001, error=0.249
# >iteration=905, lrate=0.001, error=1.482
# >iteration=906, lrate=0.001, error=2.335
# >iteration=907, lrate=0.001, error=4.665
# >iteration=908, lrate=0.001, error=34.790
# >iteration=909, lrate=0.001, error=0.478
# >iteration=910, lrate=0.001, error=5.177
# >iteration=911, lrate=0.001, error=60.060
# >iteration=912, lrate=0.001, error=15.606
# >iteration=913, lrate=0.001, error=11.494
# >iteration=914, lrate=0.001, error=6.418
# >iteration=915, lrate=0.001, error=84.831
# >iteration=916, lrate=0.001, error=23.482
# >iteration=917, lrate=0.001, error=6.502
# >iteration=918, lrate=0.001, error=45.585
# >iteration=919, lrate=0.001, error=0.841
# >iteration=920, lrate=0.001, error=0.910
# >iteration=921, lrate=0.001, error=30.529
# >iteration=922, lrate=0.001, error=0.358
# >iteration=923, lrate=0.001, error=6.097
# >iteration=924, lrate=0.001, error=247.610
# >iteration=925, lrate=0.001, error=7.022
# >iteration=926, lrate=0.001, error=8.819
# >iteration=927, lrate=0.001, error=0.037
# 927

# %%
print('Intercept: ' + str(learned_weights[0]))
print('Weights: ' + str(learned_weights.ravel()[1:]))
# Out:
# Intercept: [19.01783194]
# Weights: [-0.43795744  0.06869281 -0.75439562  1.23784664 -1.03347834  3.13439618
#  -0.146568   -1.24090478  0.6796527  -0.37264719 -1.29988125  1.03889565
#  -2.80891923]

# %%
y_pred = np.dot(X, learned_weights)

# %%
mse = (1/n) * np.sum((y-y_pred)**2)

# %%
mse
# Out:
# 36.87078611349265
